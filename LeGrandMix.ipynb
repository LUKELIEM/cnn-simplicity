# %% [markdown]
# # Le Grand Mix
# Ensemble averaging is responsible for 4-5% in test accuracy improvements for these models:
#
# 1. the Simple 5-Layer CNN (Model 1)
# 2. Wider Simple 5-Layer CNN (Model 2)
# 3. 6-layer All-CNN (Model3-5)
# 4. 7-layer All-CNN (Model3-8)
#
# We conduct an experiment to see how the improvements from ensemble averaging is dependent on:
#
# * Ensemble size
# * Model inclusion criteria
#
# Model 1 is ideal for this experiment since we have model parameter files for over 100 permutations trained to 50 epochs each. We calculate the validation and test accuracies for these 100 model permutations:
#
# * Test Accuracy - mean:0.8223, std:0.0059
# * Validation Accuracy - mean:0.8857, std:0.0066
#
# ![image.png](attachment:image.png)
#
# From these 100 model permutations, we randomly create ensembles of size 2,4, 6, 8 , 10 and 12 (200 permutations per size). For each ensemble size, we compute the means and std of test accuracies they achieve:
#
# * Ensemble size:2  acc mean:0.8458, acc std:0.0036
# * Ensemble size:4  acc mean:0.8582, acc std:0.0024
# * Ensemble size:6  acc mean:0.8624, acc std:0.0022
# * Ensemble size:8  acc mean:0.8643, acc std:0.0020
# * Ensemble size:10  acc mean:0.8656, acc std:0.0021
# * Ensemble size:12  acc mean:0.8664, acc std:0.0017
#
# As ensemble size increases, test accuracy increases and standard deviation decreases. For Model 1, an ensemble of size 10 increases test accuracy form 0.8223 to 0.8656 (an increase of 4.3%). This is in line with our results in DeepCNN-V2. Furthermore, the standard deviation decreases 3X from 0.0059 to 0.0021.
#
# *** So in a nutshell, ensemble of 8-12 is almost always a good thing!!! ***

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torch.utils.data import sampler
from torch.optim.lr_scheduler import StepLR

import torchvision
import torchvision.datasets as dset
import torchvision.transforms as T

import os
import numpy as np
import timeit
import time
import platform
import random
import pickle as pickle
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

print("Python version: ", platform.python_version())
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Python version:  3.6.4

# %%
import torchvision.transforms as transforms

class ChunkSampler(sampler.Sampler):
    """Samples elements sequentially from some offset. 
    Arguments:
        num_samples: # of desired datapoints
        start: offset where we should start selecting from
    """
    def __init__(self, num_samples, start = 0):
        self.num_samples = num_samples
        self.start = start

    def __iter__(self):
        return iter(range(self.start, self.start + self.num_samples))

    def __len__(self):
        return self.num_samples

NUM_TRAIN = 48000
NUM_VAL = 2000
NUM_TRAIN_SMALL=1000

# The output of torchvision datasets are PILImage images of range [0, 1]. 
# We transform them to Tensors of normalized range [-1, 1]
transform = transforms.Compose([
    # transforms.RandomResizedCrop(32),  # data augmentation - random crop
    transforms.RandomHorizontalFlip(),      # data augmentation - horizontal flip
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

cifar10_train = dset.CIFAR10('./cs231n/datasets', train=True, download=True,
                           transform=transform)
loader_train = DataLoader(cifar10_train, batch_size=64, sampler=ChunkSampler(NUM_TRAIN, 0))
loader_train_small = DataLoader(cifar10_train, batch_size=64, sampler=ChunkSampler(NUM_TRAIN_SMALL, 0))

cifar10_val = dset.CIFAR10('./cs231n/datasets', train=True, download=True, 
                           transform=transform)
loader_val = DataLoader(cifar10_val, batch_size=64, sampler=ChunkSampler(NUM_VAL, NUM_TRAIN))

cifar10_test = dset.CIFAR10('./cs231n/datasets', train=False, download=True, 
                          transform=transform)
loader_test = DataLoader(cifar10_test, batch_size=64)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
cpu_dtype = torch.FloatTensor # the CPU datatype
gpu_dtype = torch.cuda.FloatTensor

# Constant to control how frequently we print train loss
print_every = 100

# This is a little utility that we'll use to reset the model
# if we want to re-initialize all our parameters
def reset(m):
    if hasattr(m, 'reset_parameters'):
        m.reset_parameters()
        
class Flatten(nn.Module):
    def forward(self, x):
        N, C, H, W = x.size() # read in N, C, H, W
        return x.view(N, -1)  # "flatten" the C * H * W values into a single vector per image

def check_accuracy(model, loader, verbose=False, dtype=gpu_dtype):
    if verbose:
        if loader.dataset.train:
            print('Checking accuracy on validation set')
        else:
            print('Checking accuracy on test set')   
    num_correct = 0
    num_samples = 0
    model.eval() # Put the model in test mode (the opposite of model.train(), essentially)
    for x, y in loader:
        x_var = Variable(x.type(dtype), volatile=True)

        scores = model(x_var)
        _, preds = scores.data.cpu().max(1)
        num_correct += (preds == y).sum()
        num_samples += preds.size(0)
    acc = float(num_correct) / num_samples
    if verbose:
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
    return acc

def create_ensemble(files, num_models):
    """
    This function generate an ensemble of a specified size randomly from files.
    """
    
    # Randomly generate ensemble
    ensemble = []
    selection = np.random.choice(len(files), num_models,replace=False)
    for n in selection:
        ensemble.append(files[n])
    return ensemble  

def load_ensemble_models(ensemble, generator):
    """
    This function load an ensemble of models with files provided
    """
    
    for n in range(len(ensemble)):
        model = generator().type(gpu_dtype)
   
        # Load trained parameters into model
        file_name = ensemble[n]
        model.load_state_dict(torch.load(file_name))
        model.eval() # Put the model in test mode (the opposite of model.train(), essentially)    

        models.append(model)  # Create a list of models 
    return models

def calc_ensemble_accuracy(models):
    """
    This function load an ensemble of models with files provided
    """
    num_correct = 0
    num_samples = 0
    i = 0

    for x, y in loader_test:
        x_var = Variable(x.type(gpu_dtype), volatile=True)
        num_samples += x.size()[0]
        scores_sum = torch.zeros(x.size()[0],10).type(gpu_dtype)
    
        for n in range(len(models)):
            scores = models[n](x_var)
            scores_sum += scores.data

        y_pred = scores_sum.cpu().max(1)[1]
        num_correct += (y_pred == y).sum()

    return float(num_correct) / num_samples  # ensemble test accuracy

# %%
def generator_m1():

    # Model1 - 5 layer Conv Layers (WIDE)

    model = nn.Sequential(
                    nn.Conv2d(in_channels=3,out_channels=64,kernel_size=3,stride=1,padding=1), # preserve dimension
                    nn.ReLU(inplace=True),
                    nn.BatchNorm2d(num_features=64),
                    nn.Conv2d(in_channels=64,out_channels=128,kernel_size=3,stride=1,padding=1), # preserve dimension
                    nn.ReLU(inplace=True),
                    nn.BatchNorm2d(num_features=128),
                    nn.Conv2d(in_channels=128,out_channels=128,kernel_size=3,stride=1,padding=1), # preserve dimension
                    nn.ReLU(inplace=True),
                    nn.BatchNorm2d(num_features=128),
                    nn.MaxPool2d(kernel_size=2,stride=2),  # Downsample by half
                    nn.Conv2d(in_channels=128,out_channels=256,kernel_size=3,stride=1,padding=1), # preserve dimension
                    nn.ReLU(inplace=True),
                    nn.BatchNorm2d(num_features=256),
                    nn.Conv2d(in_channels=256,out_channels=256,kernel_size=3,stride=1,padding=1), # preserve dimension
                    nn.ReLU(inplace=True),
                    nn.BatchNorm2d(num_features=256),
                    nn.MaxPool2d(kernel_size=2,stride=2),  # Downsample by half        
                    Flatten(),
                    nn.Linear(16384,1024),  # 5408=128*16*16 input size
                    nn.BatchNorm1d(1024),
                    nn.ReLU(inplace=True),
                    nn.Linear(1024,10),
                    )
    
    
    return model


def generator_m2():

    # Model2 - Original Simple 5 layer Conv Layers

    model = nn.Sequential(
                    nn.Conv2d(in_channels=3,out_channels=32,kernel_size=3,stride=1,padding=1), # preserve dimension
                    nn.ReLU(inplace=True),
                    nn.BatchNorm2d(num_features=32),
                    nn.Conv2d(in_channels=32,out_channels=64,kernel_size=3,stride=1,padding=1), # preserve dimension
                    nn.ReLU(inplace=True),
                    nn.BatchNorm2d(num_features=64),
                    nn.Conv2d(in_channels=64,out_channels=64,kernel_size=3,stride=1,padding=1), # preserve dimension
                    nn.ReLU(inplace=True),
                    nn.BatchNorm2d(num_features=64),
                    nn.MaxPool2d(kernel_size=2,stride=2),  # Downsample by half
                    nn.Conv2d(in_channels=64,out_channels=128,kernel_size=3,stride=1,padding=1), # preserve dimension
                    nn.ReLU(inplace=True),
                    nn.BatchNorm2d(num_features=128),
                    nn.Conv2d(in_channels=128,out_channels=128,kernel_size=3,stride=1,padding=1), # preserve dimension
                    nn.ReLU(inplace=True),
                    nn.BatchNorm2d(num_features=128),
                    nn.MaxPool2d(kernel_size=2,stride=2),  # Downsample by half        
                    Flatten(),
                    nn.Linear(8192,512),  # 5408=128*16*16 input size
                    nn.BatchNorm1d(512),
                    nn.ReLU(inplace=True),
                    nn.Linear(512,10),
                    )
    
    
    return model  


def generator_m35():

    # Model3-5 - Wide 6 layer Conv Layers - replace 1st maxpools with conv(stride=2)

    model = nn.Sequential(
                    nn.Conv2d(in_channels=3,out_channels=64,kernel_size=3,stride=1,padding=1), # preserve dimension
                    nn.ReLU(inplace=True),
                    nn.BatchNorm2d(num_features=64),
                    nn.Conv2d(in_channels=64,out_channels=64,kernel_size=3,stride=1,padding=1), # preserve dimension
                    nn.ReLU(inplace=True),
                    nn.BatchNorm2d(num_features=64),
                    nn.Conv2d(in_channels=64,out_channels=128,kernel_size=3,stride=1,padding=1), # preserve dimension
                    nn.ReLU(inplace=True),
                    nn.BatchNorm2d(num_features=128),
                    nn.Conv2d(in_channels=128,out_channels=128,kernel_size=3,stride=2,padding=1), # 2:1 downsample
                    nn.ReLU(inplace=True),
                    nn.BatchNorm2d(num_features=128),        
                    nn.Conv2d(in_channels=128,out_channels=256,kernel_size=3,stride=1,padding=1), # preserve dimension
                    nn.ReLU(inplace=True),
                    nn.BatchNorm2d(num_features=256),
                    nn.Conv2d(in_channels=256,out_channels=256,kernel_size=3,stride=1,padding=1), # preserve dimension
                    nn.ReLU(inplace=True),
                    nn.BatchNorm2d(num_features=256),
                    nn.MaxPool2d(kernel_size=2,stride=2),  # Downsample by half      
                    Flatten(),
                    nn.Linear(16384,512),  # 16384=256*8*8 input size
                    nn.BatchNorm1d(512),
                    nn.ReLU(inplace=True),
                    nn.Linear(512,10)
                    )
    return model

   

def generator_m38():

    # Model3-8 - Wide 7 layer Conv Layers - replace both maxpools with conv(stride=2)

    model = nn.Sequential(
                    nn.Conv2d(in_channels=3,out_channels=64,kernel_size=3,stride=1,padding=1), # preserve dimension
                    nn.ReLU(inplace=True),
                    nn.BatchNorm2d(num_features=64),
                    nn.Conv2d(in_channels=64,out_channels=64,kernel_size=3,stride=1,padding=1), # preserve dimension
                    nn.ReLU(inplace=True),
                    nn.BatchNorm2d(num_features=64),
                    nn.Conv2d(in_channels=64,out_channels=128,kernel_size=3,stride=1,padding=1), # preserve dimension
                    nn.ReLU(inplace=True),
                    nn.BatchNorm2d(num_features=128),
                    nn.Conv2d(in_channels=128,out_channels=128,kernel_size=3,stride=2,padding=1), # 2:1 downsample
                    nn.ReLU(inplace=True),
                    nn.BatchNorm2d(num_features=128),        
                    nn.Conv2d(in_channels=128,out_channels=256,kernel_size=3,stride=1,padding=1), # preserve dimension
                    nn.ReLU(inplace=True),
                    nn.BatchNorm2d(num_features=256),
                    nn.Conv2d(in_channels=256,out_channels=256,kernel_size=3,stride=1,padding=1), # preserve dimension
                    nn.ReLU(inplace=True),
                    nn.BatchNorm2d(num_features=256),
                    nn.Conv2d(in_channels=256,out_channels=256,kernel_size=3,stride=2,padding=1), # preserve dimension
                    nn.ReLU(inplace=True),
                    nn.BatchNorm2d(num_features=256),
                    Flatten(),
                    nn.Linear(16384,512),  # 16384=256*8*8 input size
                    nn.BatchNorm1d(512),
                    nn.ReLU(inplace=True),
                    nn.Linear(512,10)
                    )
    return model

# %% [markdown]
# ### Dimension Check
#
# Handy to check dimension when putting together a CNN architecture

# %%
generators = [generator_m1, generator_m2, generator_m35, generator_m38]

for generator in generators:
    model = generator().type(gpu_dtype)
    print (model)
    
    x_gpu = torch.randn(64, 3, 32, 32).type(gpu_dtype)
    x_var_gpu = Variable(x_gpu.type(gpu_dtype)) # Construct a PyTorch Variable out of your input data
    ans = model(x_var_gpu)        # Feed it through the model! 

    print (ans.shape)

    # Check to make sure what comes out of your model
    # is the right dimensionality... this should be True
    # if you've done everything correctly
    print (np.array_equal(np.array(ans.size()), np.array([64, 10])))
# Out:
# Sequential(
#   (0): Conv2d (3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU(inplace)
#   (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   (3): Conv2d (64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (4): ReLU(inplace)
#   (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#   (6): Conv2d (128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (7): ReLU(inplace)
#   (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#   (9): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), dilation=(1, 1))
#   (10): Conv2d (128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU(inplace)
#   (12): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#   (13): Conv2d (256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (14): ReLU(inplace)
#   (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#   (16): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), dilation=(1, 1))
#   (17): Flatten(
#   )
#   (18): Linear(in_features=16384, out_features=1024)
#   (19): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True)
#   (20): ReLU(inplace)
#   (21): Linear(in_features=1024, out_features=10)
# )
# torch.Size([64, 10])
# True
# Sequential(
#   (0): Conv2d (3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU(inplace)
#   (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True)
#   (3): Conv2d (32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (4): ReLU(inplace)
#   (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   (6): Conv2d (64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (7): ReLU(inplace)
#   (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   (9): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), dilation=(1, 1))
#   (10): Conv2d (64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU(inplace)
#   (12): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#   (13): Conv2d (128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (14): ReLU(inplace)
#   (15): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#   (16): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), dilation=(1, 1))
#   (17): Flatten(
#   )
#   (18): Linear(in_features=8192, out_features=512)
#   (19): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True)
#   (20): ReLU(inplace)
#   (21): Linear(in_features=512, out_features=10)
# )
# torch.Size([64, 10])
# True
# Sequential(
#   (0): Conv2d (3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU(inplace)
#   (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   (3): Conv2d (64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (4): ReLU(inplace)
#   (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   (6): Conv2d (64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (7): ReLU(inplace)
#   (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#   (9): Conv2d (128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (10): ReLU(inplace)
#   (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#   (12): Conv2d (128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (13): ReLU(inplace)
#   (14): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#   (15): Conv2d (256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (16): ReLU(inplace)
#   (17): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#   (18): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), dilation=(1, 1))
#   (19): Flatten(
#   )
#   (20): Linear(in_features=16384, out_features=512)
#   (21): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True)
#   (22): ReLU(inplace)
#   (23): Linear(in_features=512, out_features=10)
# )
# torch.Size([64, 10])
# True
# Sequential(
#   (0): Conv2d (3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU(inplace)
#   (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   (3): Conv2d (64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (4): ReLU(inplace)
#   (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   (6): Conv2d (64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (7): ReLU(inplace)
#   (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#   (9): Conv2d (128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (10): ReLU(inplace)
#   (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#   (12): Conv2d (128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (13): ReLU(inplace)
#   (14): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#   (15): Conv2d (256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (16): ReLU(inplace)
#   (17): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#   (18): Conv2d (256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (19): ReLU(inplace)
#   (20): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#   (21): Flatten(
#   )
#   (22): Linear(in_features=16384, out_features=512)
#   (23): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True)
#   (24): ReLU(inplace)
#   (25): Linear(in_features=512, out_features=10)
# )
# torch.Size([64, 10])
# True

# %% [markdown]
# ## Simple 5-Layer CNN
#
# There are model parameters from 100 permutations for Simple 5-Layer CNN. We will first look at the distribution of validation and test accuracies.

# %%
m2_dir = "./m2-50ep-results/"

accuracies =[]
files = os.listdir(m2_dir)

for file_name in files:
    best_model = generator_m2().type(gpu_dtype)
    file_path = m2_dir+file_name
    best_model.load_state_dict(torch.load(file_path))
    
    test_acc = check_accuracy(best_model, loader_test, dtype=gpu_dtype)
    val_acc = check_accuracy(best_model, loader_val, dtype=gpu_dtype)

    print ("test acc={:.4f}  val acc={:.4f} ".format(test_acc, val_acc))
    accuracies.append([test_acc, val_acc, file_path])
# Out:
# test acc=0.8225  val acc=0.8830
# test acc=0.8273  val acc=0.8965
# test acc=0.8216  val acc=0.8835
# test acc=0.8162  val acc=0.8745
# test acc=0.8100  val acc=0.8830
# test acc=0.8277  val acc=0.8955
# test acc=0.8216  val acc=0.8830
# test acc=0.8225  val acc=0.8880
# test acc=0.8233  val acc=0.8930
# test acc=0.8107  val acc=0.8815
# test acc=0.8259  val acc=0.8800
# test acc=0.8177  val acc=0.8855
# test acc=0.8337  val acc=0.8930
# test acc=0.8165  val acc=0.8750
# test acc=0.8052  val acc=0.8820
# test acc=0.8174  val acc=0.8845
# test acc=0.8223  val acc=0.8790
# test acc=0.8262  val acc=0.8900
# test acc=0.8222  val acc=0.8695
# test acc=0.8274  val acc=0.8910
# test acc=0.8200  val acc=0.8770
# test acc=0.8202  val acc=0.8830
# test acc=0.8296  val acc=0.8945
# test acc=0.8361  val acc=0.8900
# test acc=0.8325  val acc=0.9015
# test acc=0.8122  val acc=0.8745
# test acc=0.8131  val acc=0.8865
# test acc=0.8231  val acc=0.8900
# test acc=0.8223  val acc=0.8900
# test acc=0.8282  val acc=0.8940
# test acc=0.8267  val acc=0.8920
# test acc=0.8315  val acc=0.8835
# test acc=0.8043  val acc=0.8715
# test acc=0.8156  val acc=0.8865
# test acc=0.8203  val acc=0.8795
# test acc=0.8252  val acc=0.8905
# test acc=0.8305  val acc=0.8975
# test acc=0.8222  val acc=0.8795
# test acc=0.8272  val acc=0.8840
# test acc=0.8273  val acc=0.8915
# test acc=0.8176  val acc=0.8775
# test acc=0.8226  val acc=0.8825
# test acc=0.8188  val acc=0.8900
# test acc=0.8167  val acc=0.8870
# test acc=0.8284  val acc=0.8855
# test acc=0.8264  val acc=0.8850
# test acc=0.8221  val acc=0.8890
# test acc=0.8231  val acc=0.8890
# test acc=0.8263  val acc=0.8795
# test acc=0.8185  val acc=0.8805
# test acc=0.8268  val acc=0.8810
# test acc=0.8248  val acc=0.8835
# test acc=0.8228  val acc=0.8805
# test acc=0.8218  val acc=0.8795
# test acc=0.8177  val acc=0.8865
# test acc=0.8255  val acc=0.8885
# test acc=0.8235  val acc=0.8930
# test acc=0.8076  val acc=0.8735
# test acc=0.8223  val acc=0.8895
# test acc=0.8199  val acc=0.8840
# test acc=0.8205  val acc=0.8895
# test acc=0.8161  val acc=0.8875
# test acc=0.8236  val acc=0.8790
# test acc=0.8292  val acc=0.8920
# test acc=0.8282  val acc=0.8900
# test acc=0.8176  val acc=0.8790
# test acc=0.8243  val acc=0.8895
# test acc=0.8230  val acc=0.8850
# test acc=0.8241  val acc=0.8845
# test acc=0.8189  val acc=0.8910
# test acc=0.8178  val acc=0.8775
# test acc=0.8205  val acc=0.8850
# test acc=0.8275  val acc=0.8915
# test acc=0.8284  val acc=0.8855
# test acc=0.8240  val acc=0.8870
# test acc=0.8303  val acc=0.8830
# test acc=0.8267  val acc=0.8860
# test acc=0.8224  val acc=0.8765
# test acc=0.8226  val acc=0.8765
# test acc=0.8287  val acc=0.8890
# test acc=0.8154  val acc=0.8730
# test acc=0.8156  val acc=0.8865
# test acc=0.8248  val acc=0.8810
# test acc=0.8158  val acc=0.8880
# test acc=0.8211  val acc=0.8805
# test acc=0.8077  val acc=0.8780
# test acc=0.8327  val acc=0.8900
# test acc=0.8312  val acc=0.8940
# test acc=0.8231  val acc=0.8865
# test acc=0.8253  val acc=0.8905
# test acc=0.8223  val acc=0.8880
# test acc=0.8232  val acc=0.8850
# test acc=0.8158  val acc=0.8810
# test acc=0.8270  val acc=0.8905
# test acc=0.8209  val acc=0.8865
# test acc=0.8291  val acc=0.8885
# test acc=0.8293  val acc=0.8860
# test acc=0.8051  val acc=0.8695
# test acc=0.8219  val acc=0.8870
# test acc=0.8277  val acc=0.8935
# test acc=0.8222  val acc=0.8950

# %%
sorted_list = sorted(accuracies, key=lambda x: x[1], reverse=True)   # sort file list by validation accuracy

for record in sorted_list:
    print ("test acc={:.4f}  val acc={:.4f}  Model:{}".format(record[0],record[1],record[2]))
# Out:
# test acc=0.8325  val acc=0.9015  Model:./m2-50ep-results/model2_reg=6.8983e-07lr=1.2029e-03ep=50bestacc.pt
# test acc=0.8305  val acc=0.8975  Model:./m2-50ep-results/model2_reg=6.1658e-08lr=2.0773e-03ep=50bestacc.pt
# test acc=0.8273  val acc=0.8965  Model:./m2-50ep-results/model2_reg=2.3648e-07lr=1.9457e-03ep=50bestacc.pt
# test acc=0.8277  val acc=0.8955  Model:./m2-50ep-results/model2_reg=6.8838e-07lr=2.0638e-03ep=50bestacc.pt
# test acc=0.8222  val acc=0.8950  Model:./m2-50ep-results/model2_reg=9.3270e-07lr=1.8101e-03ep=50bestacc.pt
# test acc=0.8296  val acc=0.8945  Model:./m2-50ep-results/model2_reg=9.2765e-07lr=2.2260e-03ep=50bestacc.pt
# test acc=0.8282  val acc=0.8940  Model:./m2-50ep-results/model2_reg=6.2373e-07lr=1.8293e-03ep=50bestacc.pt
# test acc=0.8312  val acc=0.8940  Model:./m2-50ep-results/model2_reg=7.8465e-07lr=1.1244e-03ep=50bestacc.pt
# test acc=0.8277  val acc=0.8935  Model:./m2-50ep-results/model2_reg=5.5080e-08lr=2.6722e-03ep=50bestacc.pt
# test acc=0.8233  val acc=0.8930  Model:./m2-50ep-results/model2_reg=9.0743e-07lr=1.1935e-03ep=50bestacc.pt
# test acc=0.8337  val acc=0.8930  Model:./m2-50ep-results/model2_reg=2.1807e-07lr=1.0457e-03ep=50bestacc.pt
# test acc=0.8235  val acc=0.8930  Model:./m2-50ep-results/model2_reg=3.1897e-07lr=2.3444e-03ep=50bestacc.pt
# test acc=0.8267  val acc=0.8920  Model:./m2-50ep-results/model2_reg=9.3219e-07lr=1.9515e-03ep=50bestacc.pt
# test acc=0.8292  val acc=0.8920  Model:./m2-50ep-results/model2_reg=1.6566e-07lr=1.0895e-03ep=50bestacc.pt
# test acc=0.8273  val acc=0.8915  Model:./m2-50ep-results/model2_reg=7.7962e-07lr=1.0278e-03ep=50bestacc.pt
# test acc=0.8275  val acc=0.8915  Model:./m2-50ep-results/model2_reg=5.2719e-07lr=1.5017e-03ep=50bestacc.pt
# test acc=0.8274  val acc=0.8910  Model:./m2-50ep-results/model2_reg=1.0000e-07lr=1.4898e-03ep=50bestacc.pt
# test acc=0.8189  val acc=0.8910  Model:./m2-50ep-results/model2_reg=9.0546e-07lr=2.9537e-03ep=50bestacc.pt
# test acc=0.8252  val acc=0.8905  Model:./m2-50ep-results/model2_reg=3.9425e-07lr=1.8528e-03ep=50bestacc.pt
# test acc=0.8253  val acc=0.8905  Model:./m2-50ep-results/model2_reg=4.2445e-07lr=1.0019e-03ep=50bestacc.pt
# test acc=0.8270  val acc=0.8905  Model:./m2-50ep-results/model2_reg=6.2922e-07lr=2.2153e-03ep=50bestacc.pt
# test acc=0.8262  val acc=0.8900  Model:./m2-50ep-results/model2_reg=2.9615e-07lr=1.8221e-03ep=50bestacc.pt
# test acc=0.8361  val acc=0.8900  Model:./m2-50ep-results/model2_reg=5.0808e-07lr=1.7347e-03ep=50bestacc.pt
# test acc=0.8231  val acc=0.8900  Model:./m2-50ep-results/model2_reg=9.4113e-07lr=2.6464e-03ep=50bestacc.pt
# test acc=0.8223  val acc=0.8900  Model:./m2-50ep-results/model2_reg=8.1114e-08lr=2.8759e-03ep=50bestacc.pt
# test acc=0.8188  val acc=0.8900  Model:./m2-50ep-results/model2_reg=1.4985e-07lr=2.0060e-03ep=50bestacc.pt
# test acc=0.8282  val acc=0.8900  Model:./m2-50ep-results/model2_reg=5.0241e-07lr=2.0707e-03ep=50bestacc.pt
# test acc=0.8327  val acc=0.8900  Model:./m2-50ep-results/model2_reg=2.1457e-07lr=1.1381e-03ep=50bestacc.pt
# test acc=0.8223  val acc=0.8895  Model:./m2-50ep-results/model2_reg=2.0764e-07lr=2.3093e-03ep=50bestacc.pt
# test acc=0.8205  val acc=0.8895  Model:./m2-50ep-results/model2_reg=4.1310e-07lr=1.7359e-03ep=50bestacc.pt
# test acc=0.8243  val acc=0.8895  Model:./m2-50ep-results/model2_reg=6.3784e-07lr=1.6415e-03ep=50bestacc.pt
# test acc=0.8221  val acc=0.8890  Model:./m2-50ep-results/model2_reg=8.0645e-07lr=2.8098e-03ep=50bestacc.pt
# test acc=0.8231  val acc=0.8890  Model:./m2-50ep-results/model2_reg=2.1750e-07lr=2.0037e-03ep=50bestacc.pt
# test acc=0.8287  val acc=0.8890  Model:./m2-50ep-results/model2_reg=9.0108e-07lr=1.4887e-03ep=50bestacc.pt
# test acc=0.8255  val acc=0.8885  Model:./m2-50ep-results/model2_reg=2.6560e-07lr=2.1574e-03ep=50bestacc.pt
# test acc=0.8291  val acc=0.8885  Model:./m2-50ep-results/model2_reg=3.6167e-07lr=1.3457e-03ep=50bestacc.pt
# test acc=0.8225  val acc=0.8880  Model:./m2-50ep-results/model2_reg=5.2456e-07lr=1.3131e-03ep=50bestacc.pt
# test acc=0.8158  val acc=0.8880  Model:./m2-50ep-results/model2_reg=4.1178e-07lr=2.3090e-03ep=50bestacc.pt
# test acc=0.8223  val acc=0.8880  Model:./m2-50ep-results/model2_reg=3.9199e-07lr=1.1468e-03ep=50bestacc.pt
# test acc=0.8161  val acc=0.8875  Model:./m2-50ep-results/model2_reg=5.2116e-07lr=1.9090e-03ep=50bestacc.pt
# test acc=0.8167  val acc=0.8870  Model:./m2-50ep-results/model2_reg=6.0737e-07lr=2.9412e-03ep=50bestacc.pt
# test acc=0.8240  val acc=0.8870  Model:./m2-50ep-results/model2_reg=4.3827e-07lr=2.5185e-03ep=50bestacc.pt
# test acc=0.8219  val acc=0.8870  Model:./m2-50ep-results/model2_reg=1.8538e-07lr=1.8851e-03ep=50bestacc.pt
# test acc=0.8131  val acc=0.8865  Model:./m2-50ep-results/model2_reg=8.2405e-07lr=2.9986e-03ep=50bestacc.pt
# test acc=0.8156  val acc=0.8865  Model:./m2-50ep-results/model2_reg=9.5114e-08lr=2.9338e-03ep=50bestacc.pt
# test acc=0.8177  val acc=0.8865  Model:./m2-50ep-results/model2_reg=8.9335e-07lr=2.7476e-03ep=50bestacc.pt
# test acc=0.8156  val acc=0.8865  Model:./m2-50ep-results/model2_reg=3.0475e-07lr=2.7241e-03ep=50bestacc.pt
# test acc=0.8231  val acc=0.8865  Model:./m2-50ep-results/model2_reg=6.7257e-07lr=2.4948e-03ep=50bestacc.pt
# test acc=0.8209  val acc=0.8865  Model:./m2-50ep-results/model2_reg=6.6331e-07lr=2.0092e-03ep=50bestacc.pt
# test acc=0.8267  val acc=0.8860  Model:./m2-50ep-results/model2_reg=5.1383e-08lr=2.0657e-03ep=50bestacc.pt
# test acc=0.8293  val acc=0.8860  Model:./m2-50ep-results/model2_reg=8.7498e-07lr=1.6410e-03ep=50bestacc.pt
# test acc=0.8177  val acc=0.8855  Model:./m2-50ep-results/model2_reg=9.4549e-07lr=2.6784e-03ep=50bestacc.pt
# test acc=0.8284  val acc=0.8855  Model:./m2-50ep-results/model2_reg=9.1379e-07lr=1.1678e-03ep=50bestacc.pt
# test acc=0.8284  val acc=0.8855  Model:./m2-50ep-results/model2_reg=7.3549e-07lr=2.2459e-03ep=50bestacc.pt
# test acc=0.8264  val acc=0.8850  Model:./m2-50ep-results/model2_reg=5.2950e-07lr=1.7552e-03ep=50bestacc.pt
# test acc=0.8230  val acc=0.8850  Model:./m2-50ep-results/model2_reg=5.2881e-07lr=1.1342e-03ep=50bestacc.pt
# test acc=0.8205  val acc=0.8850  Model:./m2-50ep-results/model2_reg=5.0451e-08lr=2.9481e-03ep=50bestacc.pt
# test acc=0.8232  val acc=0.8850  Model:./m2-50ep-results/model2_reg=8.0924e-07lr=1.9370e-03ep=50bestacc.pt
# test acc=0.8174  val acc=0.8845  Model:./m2-50ep-results/model2_reg=9.4106e-07lr=1.8933e-03ep=50bestacc.pt
# test acc=0.8241  val acc=0.8845  Model:./m2-50ep-results/model2_reg=5.1411e-07lr=1.3936e-03ep=50bestacc.pt
# test acc=0.8272  val acc=0.8840  Model:./m2-50ep-results/model2_reg=8.1828e-07lr=1.9340e-03ep=50bestacc.pt
# test acc=0.8199  val acc=0.8840  Model:./m2-50ep-results/model2_reg=7.2470e-07lr=2.6229e-03ep=50bestacc.pt
# test acc=0.8216  val acc=0.8835  Model:./m2-50ep-results/model2_reg=4.2469e-07lr=2.0889e-03ep=50bestacc.pt
# test acc=0.8315  val acc=0.8835  Model:./m2-50ep-results/model2_reg=5.6252e-08lr=1.2009e-03ep=50bestacc.pt
# test acc=0.8248  val acc=0.8835  Model:./m2-50ep-results/model2_reg=7.2867e-07lr=1.4721e-03ep=50bestacc.pt
# test acc=0.8225  val acc=0.8830  Model:./m2-50ep-results/model2_reg=9.5255e-07lr=1.6798e-03ep=50bestacc.pt
# test acc=0.8100  val acc=0.8830  Model:./m2-50ep-results/model2_reg=6.9421e-07lr=2.7902e-03ep=50bestacc.pt
# test acc=0.8216  val acc=0.8830  Model:./m2-50ep-results/model2_reg=1.5071e-07lr=1.9809e-03ep=50bestacc.pt
# test acc=0.8202  val acc=0.8830  Model:./m2-50ep-results/model2_reg=1.8985e-07lr=2.8761e-03ep=50bestacc.pt
# test acc=0.8303  val acc=0.8830  Model:./m2-50ep-results/model2_reg=8.9547e-07lr=1.3163e-03ep=50bestacc.pt
# test acc=0.8226  val acc=0.8825  Model:./m2-50ep-results/model2_reg=9.0329e-07lr=2.7813e-03ep=50bestacc.pt
# test acc=0.8052  val acc=0.8820  Model:./m2-50ep-results/model2_reg=4.7892e-07lr=2.8265e-03ep=50bestacc.pt
# test acc=0.8107  val acc=0.8815  Model:./m2-50ep-results/model2_reg=8.2342e-07lr=2.9666e-03ep=50bestacc.pt
# test acc=0.8268  val acc=0.8810  Model:./m2-50ep-results/model2_reg=1.8990e-07lr=1.9655e-03ep=50bestacc.pt
# test acc=0.8248  val acc=0.8810  Model:./m2-50ep-results/model2_reg=1.1231e-07lr=1.8590e-03ep=50bestacc.pt
# test acc=0.8158  val acc=0.8810  Model:./m2-50ep-results/model2_reg=3.4583e-07lr=1.8766e-03ep=50bestacc.pt
# test acc=0.8185  val acc=0.8805  Model:./m2-50ep-results/model2_reg=4.7419e-07lr=2.9540e-03ep=50bestacc.pt
# test acc=0.8228  val acc=0.8805  Model:./m2-50ep-results/model2_reg=9.5223e-07lr=1.6489e-03ep=50bestacc.pt
# test acc=0.8211  val acc=0.8805  Model:./m2-50ep-results/model2_reg=1.9432e-07lr=2.6622e-03ep=50bestacc.pt
# test acc=0.8259  val acc=0.8800  Model:./m2-50ep-results/model2_reg=4.0011e-07lr=2.0334e-03ep=50bestacc.pt
# test acc=0.8203  val acc=0.8795  Model:./m2-50ep-results/model2_reg=8.7445e-08lr=1.8169e-03ep=50bestacc.pt
# test acc=0.8222  val acc=0.8795  Model:./m2-50ep-results/model2_reg=9.4193e-07lr=1.9848e-03ep=50bestacc.pt
# test acc=0.8263  val acc=0.8795  Model:./m2-50ep-results/model2_reg=3.7621e-07lr=2.3346e-03ep=50bestacc.pt
# test acc=0.8218  val acc=0.8795  Model:./m2-50ep-results/model2_reg=6.4751e-07lr=1.9552e-03ep=50bestacc.pt
# test acc=0.8223  val acc=0.8790  Model:./m2-50ep-results/model2_reg=8.8564e-07lr=2.1177e-03ep=50bestacc.pt
# test acc=0.8236  val acc=0.8790  Model:./m2-50ep-results/model2_reg=2.5584e-07lr=1.1692e-03ep=50bestacc.pt
# test acc=0.8176  val acc=0.8790  Model:./m2-50ep-results/model2_reg=6.9931e-07lr=2.3006e-03ep=50bestacc.pt
# test acc=0.8077  val acc=0.8780  Model:./m2-50ep-results/model2_reg=7.4289e-07lr=2.2866e-03ep=50bestacc.pt
# test acc=0.8176  val acc=0.8775  Model:./m2-50ep-results/model2_reg=2.1134e-07lr=2.9201e-03ep=50bestacc.pt
# test acc=0.8178  val acc=0.8775  Model:./m2-50ep-results/model2_reg=8.1519e-07lr=2.8225e-03ep=50bestacc.pt
# test acc=0.8200  val acc=0.8770  Model:./m2-50ep-results/model2_reg=4.3000e-07lr=2.2251e-03ep=50bestacc.pt
# test acc=0.8224  val acc=0.8765  Model:./m2-50ep-results/model2_reg=2.9565e-07lr=2.6467e-03ep=50bestacc.pt
# test acc=0.8226  val acc=0.8765  Model:./m2-50ep-results/model2_reg=1.5522e-07lr=2.1946e-03ep=50bestacc.pt
# test acc=0.8165  val acc=0.8750  Model:./m2-50ep-results/model2_reg=1.4902e-07lr=2.9114e-03ep=50bestacc.pt
# test acc=0.8162  val acc=0.8745  Model:./m2-50ep-results/model2_reg=4.6725e-07lr=2.8874e-03ep=50bestacc.pt
# test acc=0.8122  val acc=0.8745  Model:./m2-50ep-results/model2_reg=2.4920e-07lr=2.6289e-03ep=50bestacc.pt
# test acc=0.8076  val acc=0.8735  Model:./m2-50ep-results/model2_reg=6.2334e-07lr=2.0171e-03ep=50bestacc.pt
# test acc=0.8154  val acc=0.8730  Model:./m2-50ep-results/model2_reg=6.6274e-07lr=2.4895e-03ep=50bestacc.pt
# test acc=0.8043  val acc=0.8715  Model:./m2-50ep-results/model2_reg=7.8753e-07lr=2.7884e-03ep=50bestacc.pt
# test acc=0.8222  val acc=0.8695  Model:./m2-50ep-results/model2_reg=8.4779e-08lr=2.7049e-03ep=50bestacc.pt
# test acc=0.8051  val acc=0.8695  Model:./m2-50ep-results/model2_reg=6.9146e-07lr=2.8948e-03ep=50bestacc.pt

# %%
result=np.array(accuracies)

print ("Test Accuracy - mean:{:.4f}, std:{:.4f}".format(result[:,0].mean(), result[:,0].std() ))
print ("Validation Accuracy - mean:{:.4f}, std:{:.4f}".format(result[:,1].mean(), result[:,1].std() ))


plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.hist(result[:,1])
plt.xlabel('Val Accuracy')
plt.ylabel("Frequency")
plt.title("Simple 5-Layer CNN - Val Accuracy Distribution")
plt.grid(True)

plt.subplot(1, 2, 2)
plt.hist(result[:,0])
plt.xlabel('Test Accuracy')
plt.ylabel("Frequency")
plt.title("Simple 5-Layer CNN - Test Accuracy Distribution")
plt.grid(True)
plt.tight_layout()

plt.show()
# Out:
# Test Accuracy - mean:0.8223, std:0.0059
# Validation Accuracy - mean:0.8857, std:0.0066

# %% [markdown]
# ## Ensemble Size
#
# We put together randoms ensembles of 2,4,6,8 and 10 models. For each ensemble size, we look at the test accuracy distribution of these ensembles.

# %%
ensemble_sizes = [2,4,6,8,10,12]
max_count = 200  # Run random 

best_acc = 0.0
best_ensemble = []
ensemble_acc = np.zeros((max_count, len(ensemble_sizes)))
print (ensemble_acc.shape)

for size_idx, ensemble_size in enumerate(ensemble_sizes):
    
    for count in range(max_count):

        models = []

        ensemble = create_ensemble(files, ensemble_size)  # generate random ensemble of specified size
        models = load_ensemble_models(ensemble, generator_m2)   # load models with parameter files
        acc = calc_ensemble_accuracy(models)   # calculate ensemble accuracy
        
        if (acc > best_acc):   # Save the best ensemble accuracy and the ensemble model
            best_acc = acc
            best_ensemble = ensemble 
            
        ensemble_acc[count,size_idx] = acc  # Store in numpy array for analysis later
        
    print ("Ensemble size:{}  acc mean:{:.4f}, acc std:{:.4f}".format(ensemble_size, \
                                    ensemble_acc[:,size_idx].mean(), ensemble_acc[:,size_idx].std() ))
# Out:
# (200, 6)
# Ensemble size:2  acc mean:0.8458, acc std:0.0036
# Ensemble size:4  acc mean:0.8582, acc std:0.0024
# Ensemble size:6  acc mean:0.8624, acc std:0.0022
# Ensemble size:8  acc mean:0.8643, acc std:0.0020
# Ensemble size:10  acc mean:0.8656, acc std:0.0021
# Ensemble size:12  acc mean:0.8664, acc std:0.0017

# %% [markdown]
# ## Best Ensemble
#
# The best ensemble test accuracy achieved is 87.24% in after 1200 permutation runs. This is slightly lower than the 87.45% ensemble I got in DeepCNN-V2.

# %%
print (best_acc)
print (best_ensemble)
print (len(best_ensemble))
# Out:
# 0.8724
# ['model2_reg=4.1178e-07lr=2.3090e-03ep=50bestacc.pt', 'model2_reg=8.1519e-07lr=2.8225e-03ep=50bestacc.pt', 'model2_reg=4.3000e-07lr=2.2251e-03ep=50bestacc.pt', 'model2_reg=6.1658e-08lr=2.0773e-03ep=50bestacc.pt', 'model2_reg=2.1807e-07lr=1.0457e-03ep=50bestacc.pt', 'model2_reg=6.8983e-07lr=1.2029e-03ep=50bestacc.pt', 'model2_reg=3.0475e-07lr=2.7241e-03ep=50bestacc.pt', 'model2_reg=6.6331e-07lr=2.0092e-03ep=50bestacc.pt', 'model2_reg=8.7445e-08lr=1.8169e-03ep=50bestacc.pt', 'model2_reg=5.1411e-07lr=1.3936e-03ep=50bestacc.pt']
# 10

# %%
ensemble_sizes = [2,4,6,8,10,12]

for size_idx, ensemble_size in enumerate(ensemble_sizes):
    print ("Simple 5-Layer CNN: Ensemble="+str(ensemble_size))
    print ("Test Accuracy - mean:{:.4f}, std:{:.4f}".format(ensemble_acc[:,size_idx].mean(), \
                                                            ensemble_acc[:,size_idx].std() ))
    plt.figure(figsize=(5, 4))
    plt.hist(ensemble_acc[:,size_idx])
    plt.xlabel('Ensemble Accuracy')
    plt.ylabel("Frequency")
    plt.title("Simple 5-Layer CNN: Ensemble="+str(ensemble_size) +" Accuracy Distribution")
    plt.grid(True)
    plt.tight_layout()

    plt.show()
# Out:
# Simple 5-Layer CNN: Ensemble=2
# Test Accuracy - mean:0.8458, std:0.0036
# Simple 5-Layer CNN: Ensemble=4
# Test Accuracy - mean:0.8582, std:0.0024
# Simple 5-Layer CNN: Ensemble=6
# Test Accuracy - mean:0.8624, std:0.0022
# Simple 5-Layer CNN: Ensemble=8
# Test Accuracy - mean:0.8643, std:0.0020
# Simple 5-Layer CNN: Ensemble=10
# Test Accuracy - mean:0.8656, std:0.0021
# Simple 5-Layer CNN: Ensemble=12
# Test Accuracy - mean:0.8664, std:0.0017

# %% [markdown]
# ## Model Filtering
#
# We will repeat the exercise in the previous section with a filtered model parameter list. Instead of all 100 permutations, we will use 50 permutations with the highest validation accuracies.

# %%
files = []

for _,_,filepath in sorted_list:   # model parameters files in descending order of validation accuracy
    files.append(filepath)
    
num_files = 50  # We create ensembles with top 50 models with highest validation accuracies

ensemble_sizes = [2,4,6,8,10,12]
max_count = 200  # Run random 

best_acc = 0.0
best_ensemble = []
ensemble_acc = np.zeros((max_count, len(ensemble_sizes)))
print (ensemble_acc.shape)

for size_idx, ensemble_size in enumerate(ensemble_sizes):
    
    for count in range(max_count):

        models = []

        ensemble = create_ensemble(files[:-(num_files+1)], ensemble_size)  # generate random ensemble of specified size
        models = load_ensemble_models(ensemble, generator_m2)   # load models with parameter files
        acc = calc_ensemble_accuracy(models)   # calculate ensemble accuracy
        
        if (acc > best_acc):   # Save the best ensemble accuracy and the ensemble model
            best_acc = acc
            best_ensemble = ensemble 
            
        ensemble_acc[count,size_idx] = acc  # Store in numpy array for analysis later
        
    print ("Ensemble size:{}  acc mean:{:.4f}, acc std:{:.4f}".format(ensemble_size, \
                                    ensemble_acc[:,size_idx].mean(), ensemble_acc[:,size_idx].std() ))
# Out:
# (200, 6)
# Ensemble size:2  acc mean:0.8475, acc std:0.0033
# Ensemble size:4  acc mean:0.8595, acc std:0.0026
# Ensemble size:6  acc mean:0.8633, acc std:0.0024
# Ensemble size:8  acc mean:0.8654, acc std:0.0020
# Ensemble size:10  acc mean:0.8663, acc std:0.0019
# Ensemble size:12  acc mean:0.8673, acc std:0.0018

# %%
print (best_acc)
print (best_ensemble)
print (len(best_ensemble))
# Out:
# 0.8724
# ['./m2-50ep-results/model2_reg=9.2765e-07lr=2.2260e-03ep=50bestacc.pt', './m2-50ep-results/model2_reg=6.6331e-07lr=2.0092e-03ep=50bestacc.pt', './m2-50ep-results/model2_reg=9.0743e-07lr=1.1935e-03ep=50bestacc.pt', './m2-50ep-results/model2_reg=2.9615e-07lr=1.8221e-03ep=50bestacc.pt', './m2-50ep-results/model2_reg=5.1383e-08lr=2.0657e-03ep=50bestacc.pt', './m2-50ep-results/model2_reg=9.3219e-07lr=1.9515e-03ep=50bestacc.pt', './m2-50ep-results/model2_reg=4.1310e-07lr=1.7359e-03ep=50bestacc.pt', './m2-50ep-results/model2_reg=8.0645e-07lr=2.8098e-03ep=50bestacc.pt', './m2-50ep-results/model2_reg=2.1457e-07lr=1.1381e-03ep=50bestacc.pt', './m2-50ep-results/model2_reg=1.4985e-07lr=2.0060e-03ep=50bestacc.pt', './m2-50ep-results/model2_reg=1.0000e-07lr=1.4898e-03ep=50bestacc.pt', './m2-50ep-results/model2_reg=2.1750e-07lr=2.0037e-03ep=50bestacc.pt']
# 12

# %%
ensemble_sizes = [2,4,6,8,10,12]

for size_idx, ensemble_size in enumerate(ensemble_sizes):
    print ("Simple 5-Layer CNN: Ensemble="+str(ensemble_size))
    print ("Test Accuracy - mean:{:.4f}, std:{:.4f}".format(ensemble_acc[:,size_idx].mean(), \
                                                            ensemble_acc[:,size_idx].std() ))
    plt.figure(figsize=(5, 4))
    plt.hist(ensemble_acc[:,size_idx])
    plt.xlabel('Ensemble Accuracy')
    plt.ylabel("Frequency")
    plt.title("Simple 5-Layer CNN: Ensemble="+str(ensemble_size) +" Accuracy Distribution")
    plt.grid(True)
    plt.tight_layout()

    plt.show()
# Out:
# Simple 5-Layer CNN: Ensemble=2
# Test Accuracy - mean:0.8475, std:0.0033
# Simple 5-Layer CNN: Ensemble=4
# Test Accuracy - mean:0.8595, std:0.0026
# Simple 5-Layer CNN: Ensemble=6
# Test Accuracy - mean:0.8633, std:0.0024
# Simple 5-Layer CNN: Ensemble=8
# Test Accuracy - mean:0.8654, std:0.0020
# Simple 5-Layer CNN: Ensemble=10
# Test Accuracy - mean:0.8663, std:0.0019
# Simple 5-Layer CNN: Ensemble=12
# Test Accuracy - mean:0.8673, std:0.0018

# %%
files = []

for _,_,filepath in sorted_list:   # model parameters files in descending order of validation accuracy
    files.append(filepath)
    
num_files = 25  # We create ensembles with top 25 models with highest validation accuracies

ensemble_sizes = [2,4,6,8,10,12]
max_count = 200  # Run random 

best_acc = 0.0
best_ensemble = []
ensemble_acc = np.zeros((max_count, len(ensemble_sizes)))
print (ensemble_acc.shape)

for size_idx, ensemble_size in enumerate(ensemble_sizes):
    
    for count in range(max_count):

        models = []

        ensemble = create_ensemble(files[:-(num_files+1)], ensemble_size)  # generate random ensemble of specified size
        models = load_ensemble_models(ensemble, generator_m2)   # load models with parameter files
        acc = calc_ensemble_accuracy(models)   # calculate ensemble accuracy
        
        if (acc > best_acc):   # Save the best ensemble accuracy and the ensemble model
            best_acc = acc
            best_ensemble = ensemble 
            
        ensemble_acc[count,size_idx] = acc  # Store in numpy array for analysis later
        
    print ("Ensemble size:{}  acc mean:{:.4f}, acc std:{:.4f}".format(ensemble_size, \
                                    ensemble_acc[:,size_idx].mean(), ensemble_acc[:,size_idx].std() ))
# Out:
# (200, 6)
# Ensemble size:2  acc mean:0.8470, acc std:0.0034
# Ensemble size:4  acc mean:0.8585, acc std:0.0025
# Ensemble size:6  acc mean:0.8626, acc std:0.0020
# Ensemble size:8  acc mean:0.8648, acc std:0.0021
# Ensemble size:10  acc mean:0.8659, acc std:0.0020
# Ensemble size:12  acc mean:0.8669, acc std:0.0018

# %%
print (best_acc)
print (best_ensemble)
print (len(best_ensemble))
# Out:
# 0.8714
# ['./m2-50ep-results/model2_reg=8.2342e-07lr=2.9666e-03ep=50bestacc.pt', './m2-50ep-results/model2_reg=5.2881e-07lr=1.1342e-03ep=50bestacc.pt', './m2-50ep-results/model2_reg=8.2405e-07lr=2.9986e-03ep=50bestacc.pt', './m2-50ep-results/model2_reg=9.2765e-07lr=2.2260e-03ep=50bestacc.pt', './m2-50ep-results/model2_reg=7.8465e-07lr=1.1244e-03ep=50bestacc.pt', './m2-50ep-results/model2_reg=6.1658e-08lr=2.0773e-03ep=50bestacc.pt', './m2-50ep-results/model2_reg=6.8983e-07lr=1.2029e-03ep=50bestacc.pt', './m2-50ep-results/model2_reg=4.3827e-07lr=2.5185e-03ep=50bestacc.pt', './m2-50ep-results/model2_reg=4.2469e-07lr=2.0889e-03ep=50bestacc.pt', './m2-50ep-results/model2_reg=9.1379e-07lr=1.1678e-03ep=50bestacc.pt']
# 10

# %%
ensemble_sizes = [2,4,6,8,10,12]

for size_idx, ensemble_size in enumerate(ensemble_sizes):
    print ("Simple 5-Layer CNN: Ensemble="+str(ensemble_size))
    print ("Test Accuracy - mean:{:.4f}, std:{:.4f}".format(ensemble_acc[:,size_idx].mean(), \
                                                            ensemble_acc[:,size_idx].std() ))
    plt.figure(figsize=(5, 4))
    plt.hist(ensemble_acc[:,size_idx])
    plt.xlabel('Ensemble Accuracy')
    plt.ylabel("Frequency")
    plt.title("Simple 5-Layer CNN: Ensemble="+str(ensemble_size) +" Accuracy Distribution")
    plt.grid(True)
    plt.tight_layout()

    plt.show()
# Out:
# Simple 5-Layer CNN: Ensemble=2
# Test Accuracy - mean:0.8470, std:0.0034
# Simple 5-Layer CNN: Ensemble=4
# Test Accuracy - mean:0.8585, std:0.0025
# Simple 5-Layer CNN: Ensemble=6
# Test Accuracy - mean:0.8626, std:0.0020
# Simple 5-Layer CNN: Ensemble=8
# Test Accuracy - mean:0.8648, std:0.0021
# Simple 5-Layer CNN: Ensemble=10
# Test Accuracy - mean:0.8659, std:0.0020
# Simple 5-Layer CNN: Ensemble=12
# Test Accuracy - mean:0.8669, std:0.0018
